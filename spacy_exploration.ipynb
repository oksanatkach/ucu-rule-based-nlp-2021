# %%
# !pip install spacy
# !python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: spacy in /Users/oksanatkach/.virtualenvs/ucu-rule-based-2021/lib/python3.7/site-packages (3.1.3)
# Requirement already satisfied: setuptools in /Users/oksanatkach/.virtualenvs/ucu-rule-based-2021/lib/python3.7/site-packages (from spacy) (58.2.0)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /Users/oksanatkach/.virtualenvs/ucu-rule-based-2021/lib/python3.7/site-packages (from spacy) (0.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/oksanatkach/.virtualenvs/ucu-rule-based-2021/lib/python3.7/site-packages (from spacy) (4.62.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/oksanatkach/.virtualenvs/ucu-rule-based-2021/lib/python3.7/site-packages (from spacy) (2.26.0)
# Requirement already satisfied: thinc<8.1.0,>=8.0.9 in /Users/oksanatkach/.virtualenvs/ucu-rule-based-2021/lib/python3.7/site-packages (from spacy) (8.0.10)
# Requirement already satisfied: packaging>=20.0 in /Users/oksanatkach/.virtualenvs/ucu-rule-based-2021/lib/python3.7/site-packages (from spacy) (21.0)
# Requirement already satisfied: pathy>=0.3.5 in /Users/oksanatkach/.virtualenvs/ucu-rule-based-2021/lib/python3.7/site-packages (from spacy) (0.6.0)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in /Users/oksanatkach/.virtualenvs/ucu-rule-based-2021/lib/python3.7/site-packages (from spacy) (3.10.0.2)
# Requirement already satisfied: jinja2 in /Users/oksanatkach/.virtualenvs/ucu-rule-based-2021/lib/python3.7/site-packages (from spacy) (3.0.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/oksanatkach/.virtualenvs/ucu-rule-based-2021/lib/python3.7/site-packages (from spacy) (2.0.6)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /Users/oksanatkach/.virtualenvs/ucu-rule-based-2021/lib/python3.7/site-packages (from spacy) (2.4.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /Users/oksanatkach/.virtualenvs/ucu-rule-based-2021/lib/python3.7/site-packages (from spacy) (1.8.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /Users/oksanatkach/.virtualenvs/ucu-rule-based-2021/lib/python3.7/site-packages (from spacy) (3.0.8)
# Requirement already satisfied: numpy>=1.15.0 in /Users/oksanatkach/.virtualenvs/ucu-rule-based-2021/lib/python3.7/site-packages (from spacy) (1.21.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /Users/oksanatkach/.virtualenvs/ucu-rule-based-2021/lib/python3.7/site-packages (from spacy) (0.8.2)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /Users/oksanatkach/.virtualenvs/ucu-rule-based-2021/lib/python3.7/site-packages (from spacy) (0.7.4)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/oksanatkach/.virtualenvs/ucu-rule-based-2021/lib/python3.7/site-packages (from spacy) (3.0.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/oksanatkach/.virtualenvs/ucu-rule-based-2021/lib/python3.7/site-packages (from spacy) (2.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/oksanatkach/.virtualenvs/ucu-rule-based-2021/lib/python3.7/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: zipp>=0.5 in /Users/oksanatkach/.virtualenvs/ucu-rule-based-2021/lib/python3.7/site-packages (from catalogue<2.1.0,>=2.0.6->spacy) (3.6.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/oksanatkach/.virtualenvs/ucu-rule-based-2021/lib/python3.7/site-packages (from packaging>=20.0->spacy) (2.4.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /Users/oksanatkach/.virtualenvs/ucu-rule-based-2021/lib/python3.7/site-packages (from pathy>=0.3.5->spacy) (5.2.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/oksanatkach/.virtualenvs/ucu-rule-based-2021/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.6)
# Requirement already satisfied: idna<4,>=2.5 in /Users/oksanatkach/.virtualenvs/ucu-rule-based-2021/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/oksanatkach/.virtualenvs/ucu-rule-based-2021/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2021.5.30)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/oksanatkach/.virtualenvs/ucu-rule-based-2021/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.7)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/oksanatkach/.virtualenvs/ucu-rule-based-2021/lib/python3.7/site-packages (from typer<0.5.0,>=0.3.0->spacy) (8.0.1)
# Requirement already satisfied: importlib-metadata in /Users/oksanatkach/.virtualenvs/ucu-rule-based-2021/lib/python3.7/site-packages (from click<9.0.0,>=7.1.1->typer<0.5.0,>=0.3.0->spacy) (4.8.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/oksanatkach/.virtualenvs/ucu-rule-based-2021/lib/python3.7/site-packages (from jinja2->spacy) (2.0.1)
# Collecting en-core-web-sm==3.1.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.1.0/en_core_web_sm-3.1.0-py3-none-any.whl (13.6 MB)
#      |████████████████████████████████| 13.6 MB 1.4 MB/s eta 0:00:01    |████████▏                       | 3.5 MB 202 kB/s eta 0:00:50     |████████████████████████████▊   | 12.2 MB 2.0 MB/s eta 0:00:01
# Requirement already satisfied: spacy<3.2.0,>=3.1.0 in /Users/oksanatkach/.virtualenvs/ucu-rule-based-2021/lib/python3.7/site-packages (from en-core-web-sm==3.1.0) (3.1.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /Users/oksanatkach/.virtualenvs/ucu-rule-based-2021/lib/python3.7/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.8.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/oksanatkach/.virtualenvs/ucu-rule-based-2021/lib/python3.7/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (4.62.3)
# Requirement already satisfied: jinja2 in /Users/oksanatkach/.virtualenvs/ucu-rule-based-2021/lib/python3.7/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.0.2)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in /Users/oksanatkach/.virtualenvs/ucu-rule-based-2021/lib/python3.7/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.10.0.2)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /Users/oksanatkach/.virtualenvs/ucu-rule-based-2021/lib/python3.7/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.7.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/oksanatkach/.virtualenvs/ucu-rule-based-2021/lib/python3.7/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.26.0)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /Users/oksanatkach/.virtualenvs/ucu-rule-based-2021/lib/python3.7/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.4.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/oksanatkach/.virtualenvs/ucu-rule-based-2021/lib/python3.7/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.0.5)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /Users/oksanatkach/.virtualenvs/ucu-rule-based-2021/lib/python3.7/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.8.2)
# Requirement already satisfied: pathy>=0.3.5 in /Users/oksanatkach/.virtualenvs/ucu-rule-based-2021/lib/python3.7/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.6.0)
# Requirement already satisfied: setuptools in /Users/oksanatkach/.virtualenvs/ucu-rule-based-2021/lib/python3.7/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (58.2.0)
# Requirement already satisfied: numpy>=1.15.0 in /Users/oksanatkach/.virtualenvs/ucu-rule-based-2021/lib/python3.7/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.21.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/oksanatkach/.virtualenvs/ucu-rule-based-2021/lib/python3.7/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.0.5)
# Requirement already satisfied: thinc<8.1.0,>=8.0.9 in /Users/oksanatkach/.virtualenvs/ucu-rule-based-2021/lib/python3.7/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (8.0.10)
# Requirement already satisfied: packaging>=20.0 in /Users/oksanatkach/.virtualenvs/ucu-rule-based-2021/lib/python3.7/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (21.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /Users/oksanatkach/.virtualenvs/ucu-rule-based-2021/lib/python3.7/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.4.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/oksanatkach/.virtualenvs/ucu-rule-based-2021/lib/python3.7/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.0.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /Users/oksanatkach/.virtualenvs/ucu-rule-based-2021/lib/python3.7/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.0.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/oksanatkach/.virtualenvs/ucu-rule-based-2021/lib/python3.7/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.0.6)
# Requirement already satisfied: zipp>=0.5 in /Users/oksanatkach/.virtualenvs/ucu-rule-based-2021/lib/python3.7/site-packages (from catalogue<2.1.0,>=2.0.6->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.6.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/oksanatkach/.virtualenvs/ucu-rule-based-2021/lib/python3.7/site-packages (from packaging>=20.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.4.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /Users/oksanatkach/.virtualenvs/ucu-rule-based-2021/lib/python3.7/site-packages (from pathy>=0.3.5->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (5.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/oksanatkach/.virtualenvs/ucu-rule-based-2021/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2021.5.30)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/oksanatkach/.virtualenvs/ucu-rule-based-2021/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/oksanatkach/.virtualenvs/ucu-rule-based-2021/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.0.6)
# Requirement already satisfied: idna<4,>=2.5 in /Users/oksanatkach/.virtualenvs/ucu-rule-based-2021/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.2)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/oksanatkach/.virtualenvs/ucu-rule-based-2021/lib/python3.7/site-packages (from typer<0.5.0,>=0.3.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (8.0.1)
# Requirement already satisfied: importlib-metadata in /Users/oksanatkach/.virtualenvs/ucu-rule-based-2021/lib/python3.7/site-packages (from click<9.0.0,>=7.1.1->typer<0.5.0,>=0.3.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (4.8.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/oksanatkach/.virtualenvs/ucu-rule-based-2021/lib/python3.7/site-packages (from jinja2->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.0.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import spacy

# %%
nlp = spacy.load('en_core_web_sm')

# %%
text = "This likely means you're already running a local web server, so there's no need to make displaCy start another one. Instead, you should be able to replace displacy.serve with displacy.render to show the visualization."

# %%
doc = nlp(text)

# %%
list(doc.sents)
# Out:
# [This likely means you're already running a local web server, so there's no need to make displaCy start another one.,
#  Instead, you should be able to replace displacy.serve with displacy.render to show the visualization.]

# %%
sentence_spans = list(doc.sents)
spacy.displacy.serve(sentence_spans, style="dep")
# Out:
# /usr/local/lib/python3.7/site-packages/spacy/displacy/__init__.py:97: UserWarning: [W011] It looks like you're calling displacy.serve from within a Jupyter notebook or a similar environment. This likely means you're already running a local web server, so there's no need to make displaCy start another one. Instead, you should be able to replace displacy.serve with displacy.render to show the visualization.
#   warnings.warn(Warnings.W011)
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="7141581ca23247299b02e4b29f434faf-0" class="displacy" width="3900" height="662.0" direction="ltr" style="max-width: none; height: 662.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">This</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">likely</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">means</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">you</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">'re</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">already</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">running</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">local</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">web</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">server,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">so</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">there</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">'s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">no</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">need</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">make</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">displaCy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">start</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">another</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">one.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7141581ca23247299b02e4b29f434faf-0-0" stroke-width="2px" d="M70,527.0 C70,352.0 380.0,352.0 380.0,527.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7141581ca23247299b02e4b29f434faf-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,529.0 L62,517.0 78,517.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7141581ca23247299b02e4b29f434faf-0-1" stroke-width="2px" d="M245,527.0 C245,439.5 375.0,439.5 375.0,527.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7141581ca23247299b02e4b29f434faf-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,529.0 L237,517.0 253,517.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7141581ca23247299b02e4b29f434faf-0-2" stroke-width="2px" d="M595,527.0 C595,264.5 1085.0,264.5 1085.0,527.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7141581ca23247299b02e4b29f434faf-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,529.0 L587,517.0 603,517.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7141581ca23247299b02e4b29f434faf-0-3" stroke-width="2px" d="M770,5
# Using the 'dep' visualizer
# Serving on http://0.0.0.0:5000 ...
#
# Shutting down server on port 5000.

# %%
token_example = doc[0]
print(token_example.ent_type_)
print(token_example.pos_)
print(token_example.tag_)
print(token_example.vector)
# Out:
# DET
# DT
# [-0.13571987 -0.25953645  0.5980234   1.0543      0.9973282   0.20679954
#  -1.1775682   0.9776583   0.827132   -0.40455437  0.40885547 -0.01581306
#  -0.4600075   0.18371391 -0.6644426  -0.6934086   1.1224751  -1.0670991
#   1.2296829   0.6481814  -0.2163907  -0.4381313  -0.8297271  -0.5973476
#   0.5033427   0.35190928 -0.02126464 -0.9231523   0.24844706 -0.42874908
#  -0.41593593 -0.303098   -0.09194261 -0.23272203 -0.35986033  0.59478164
#  -0.14595515  0.75109375  2.1420653   0.8069137   0.6573932   0.01789705
#   0.3098136  -0.642105   -0.11232674 -0.5436055  -0.5710929   0.22215533
#  -0.6134101   0.66907096  0.54487944 -0.40347102  0.04423305  1.2583436
#   0.72793984 -1.1403402  -0.26322478 -0.27574587 -0.14583966  0.03284772
#  -0.97116137 -0.25193024 -0.47947413  1.7396077  -0.4497463  -0.5423039
#  -0.3933073  -0.03255526  1.5368824   0.0155862   0.5394334   0.3945644
#  -0.793931   -0.757059   -0.5574567   0.3093553   0.02905138 -0.62371695
#  -1.1789527  -1.4453558   0.64246684 -0.27791414 -0.54465836 -0.69647247
#   0.12355158 -0.643132    0.04643971  0.04307872  0.5328554   0.08547735
#   0.12290293 -0.48121223 -0.6049068   0.9792861  -0.47182208  0.3812237 ]

# %%
dir(doc[0])
# Out:
# ['_',
#  '__bytes__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__pyx_vtable__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  'ancestors',
#  'check_flag',
#  'children',
#  'cluster',
#  'conjuncts',
#  'dep',
#  'dep_',
#  'doc',
#  'ent_id',
#  'ent_id_',
#  'ent_iob',
#  'ent_iob_',
#  'ent_kb_id',
#  'ent_kb_id_',
#  'ent_type',
#  'ent_type_',
#  'get_extension',
#  'has_dep',
#  'has_extension',
#  'has_head',
#  'has_morph',
#  'has_vector',
#  'head',
#  'i',
#  'idx',
#  'iob_strings',
#  'is_alpha',
#  'is_ancestor',
#  'is_ascii',
#  'is_bracket',
#  'is_currency',
#  'is_digit',
#  'is_left_punct',
#  'is_lower',
#  'is_oov',
#  'is_punct',
#  'is_quote',
#  'is_right_punct',
#  'is_sent_end',
#  'is_sent_start',
#  'is_space',
#  'is_stop',
#  'is_title',
#  'is_upper',
#  'lang',
#  'lang_',
#  'left_edge',
#  'lefts',
#  'lemma',
#  'lemma_',
#  'lex',
#  'lex_id',
#  'like_email',
#  'like_num',
#  'like_url',
#  'lower',
#  'lower_',
#  'morph',
#  'n_lefts',
#  'n_rights',
#  'nbor',
#  'norm',
#  'norm_',
#  'orth',
#  'orth_',
#  'pos',
#  'pos_',
#  'prefix',
#  'prefix_',
#  'prob',
#  'rank',
#  'remove_extension',
#  'right_edge',
#  'rights',
#  'sent',
#  'sent_start',
#  'sentiment',
#  'set_extension',
#  'set_morph',
#  'shape',
#  'shape_',
#  'similarity',
#  'subtree',
#  'suffix',
#  'suffix_',
#  'tag',
#  'tag_',
#  'tensor',
#  'text',
#  'text_with_ws',
#  'vector',
#  'vector_norm',
#  'vocab',
#  'whitespace_']

# %%
text = 'I work at J&L Consulting Ltd.'
doc = nlp(text)

# %%
for token in doc:
    print(token.text)
    print(token.pos_)
# Out:
# I
# PRON
# work
# VERB
# at
# ADP
# J&L
# PROPN
# Consulting
# PROPN
# Ltd.
# PROPN

# %%
from spacy.matcher import Matcher

# %%
rule = [
    {'POS':'PROPN', 'OP':'+'},
    {'TEXT': 'Ltd.'}
]


matcher = Matcher(nlp.vocab)
matcher.add("ORG", [rule])
matches = matcher(doc)
print(matches)
for _, start, end in matches:
    print(doc[start:end])
# Out:
# [(383, 4, 6), (383, 3, 6)]
# Consulting Ltd.
# J&L Consulting Ltd.

# %%
from ipymarkup import show_box_markup

# %%
def i_to_idx(matches, doc):
    spans = set()
    for match in matches:
        start_i = match[1]
        end_i = match[2]
        span = doc[start_i:end_i]
        spans.add((span[0].idx, span[0].idx + len(span.text)))
    return spans

# %%
show_box_markup(doc.text, i_to_idx(matches, doc))
# Out:
# <div class="tex2jax_ignore" style="white-space: pre-wrap">I work at <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">J&amp;L Consulting Ltd.</span><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">Consulting Ltd.</span></div>
